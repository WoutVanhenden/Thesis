# %%
# %load_ext autoreload
# %autoreload 2
from anndata import AnnData
import squidpy as sq
import scanpy as sc
import matplotlib.pyplot as plt
#%matplotlib widget
import cv2
import torch
from skimage import io, morphology
import skimage.feature as features
from scipy import ndimage
import time
from tqdm.notebook import tqdm
import scipy
import seaborn as sns
import skimage
from skimage.measure import regionprops, regionprops_table, approximate_polygon
from shapely.geometry import Polygon
from shapely.geometry.polygon import LinearRing
import geopandas
import scanpy as sc
import rasterio
from rasterio import features
import shapely
from shapely.geometry import Point, Polygon
import matplotlib
from matplotlib.colors import Normalize
import spatialdata as sd
import napari
import numpy as np
import pandas as pd
from spatialdata import read_zarr
import napari_sparrow as sp
import os
import seaborn as sns 
os.environ["USE_PYGEOS"] = "0"
# Out:
# /home/wout/mambaforge/envs/napari-sparrow/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_23370/3484544265.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas
# /home/wout/mambaforge/envs/napari-sparrow/lib/python3.10/site-packages/spatialdata/__init__.py:9: UserWarning: Geopandas was set to use PyGEOS, changing to shapely 2.0 with:
#
# 	geopandas.options.use_pygeos = True
#
# If you intended to use PyGEOS, set the option to False.
#   _check_geopandas_using_shapely()
# the value of the environment variable BASIC_DCT_BACKEND is not in ["JAX","SCIPY"]

# %% [markdown]
# ## Read in the data

# %%
OUTPUT_DIR = '/home/wout/Documents/Thesis_lokaal/Mouse_Liver_Resolve_Data/A1-1'
sdata = read_zarr(os.path.join(  OUTPUT_DIR, 'sdata.zarr'  ) )
name_anndata = "anndataNucA11"
anndata = sc.read(OUTPUT_DIR + '/' + name_anndata + '_all_0threshold')

# %%
sdata
# Out:
# SpatialData object with:
# ├── Images
# │     ├── 'clahe': SpatialImage[cyx] (1, 12864, 10720)
# │     ├── 'min_max_filtered': SpatialImage[cyx] (1, 12864, 10720)
# │     ├── 'raw_image': SpatialImage[cyx] (1, 12864, 10720)
# │     ├── 'tiling_correction': SpatialImage[cyx] (1, 12864, 10720)
# │     └── 'transcript_density': SpatialImage[cyx] (1, 12864, 10720)
# ├── Labels
# │     └── 'segmentation_mask': SpatialImage[yx] (12864, 10720)
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (4754932, 3) (2D points)
# ├── Shapes
# │     ├── 'expanded_cells20': GeoDataFrame shape: (11283, 1) (2D shapes)
# │     ├── 'filtered_segmentation_mask_boundaries_low_counts': GeoDataFrame shape: (369, 1) (2D shapes)
# │     ├── 'filtered_segmentation_mask_boundaries_segmentation': GeoDataFrame shape: (76, 1) (2D shapes)
# │     ├── 'filtered_segmentation_mask_boundaries_size': GeoDataFrame shape: (275, 1) (2D shapes)
# │     ├── 'segmentation_mask_boundaries': GeoDataFrame shape: (11283, 1) (2D shapes)
# │     └── 'to_plot_napari': GeoDataFrame shape: (11283, 1) (2D shapes)
# └── Table
#       └── AnnData object with n_obs × n_vars = 11283 × 99
#     obs: 'region', 'instance', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_2_genes', 'pct_counts_in_top_5_genes', 'n_counts', 'shapeSize', 'leiden', 'portal_vein_EC45', 'LSEC45', 'LSEC Portal', 'LSEC Central', 'central_vein_EC45', 'stellateAll', 'stellate PeriPortal', 'stellate PeriCentral', 'FibroblastAll', 'fibroblastPortal', 'FibroblastsCentral', 'VSMC', 'capsular_fibroblasts45', 'Mesothelial cells', 'Hepatocytes', 'HepatocytesPortal', 'HepatocytesCentral', 'Cholangiocytes', 'cDC2s', 'Mig. cDCs', 'Neutrophils', 'Basophils', 'NK cells', 'ILC1s', 'T cells', 'pDCs', 'B cells', 'cDC1s', 'Kupffer cells', 'Capsule and Central Vein Mac', 'Portal LAM macrophages', 'Monocytes', 'LECs', 'cleanliness_score_genes_original_BasicMartin_12', 'annotation_score_genes_original_BasicMartin_12', 'annotationSave', 'Hep', 'score_celltype_own_score_genes_BasicMartin_12', 'second_score_celltype_own_score_genes_BasicMartin_12', 'cleanliness_own_score_genes_BasicMartin_12', 'annotation_own_score_genes_start_iterative_BasicMartin_12', 'annotation_own_score_genes_BasicMartin_12', 'annotation_score_genes_original_HLMartin_12', 'cleanliness_score_genes_original_HLMartin_12', 'score_celltype_own_score_genes_HLMartin_12', 'second_score_celltype_own_score_genes_HLMartin_12', 'cleanliness_own_score_genes_HLMartin_12', 'annotation_own_score_genes_start_iterative_HLMartin_12', 'annotation_own_score_genes_HLMartin_12', 'annotation_score_genes_original_Atlas_12', 'cleanliness_score_genes_original_Atlas_12', 'score_celltype_own_score_genes_Atlas_12', 'second_score_celltype_own_score_genes_Atlas_12', 'cleanliness_own_score_genes_Atlas_12', 'annotation_own_score_genes_start_iterative_Atlas_12', 'annotation_own_score_genes_Atlas_12', 'annotation_score_genes_original_Atlas_Scores_12', 'cleanliness_score_genes_original_Atlas_Scores_12', 'score_celltype_own_score_genes_Atlas_Scores_12', 'second_score_celltype_own_score_genes_Atlas_Scores_12', 'cleanliness_own_score_genes_Atlas_Scores_12', 'annotation_own_score_genes_start_iterative_Atlas_Scores_12', 'annotation_own_score_genes_Atlas_Scores_12', 'annotation_score_genes_original_Atlas_7', 'cleanliness_score_genes_original_Atlas_7', 'score_celltype_own_score_genes_Atlas_7', 'second_score_celltype_own_score_genes_Atlas_7', 'cleanliness_own_score_genes_Atlas_7', 'annotation_own_score_genes_start_iterative_Atlas_7', 'annotation_own_score_genes_Atlas_7', 'annotation_score_genes_original_Atlas_Scores_7', 'cleanliness_score_genes_original_Atlas_Scores_7', 'score_celltype_own_score_genes_Atlas_Scores_7', 'second_score_celltype_own_score_genes_Atlas_Scores_7', 'cleanliness_own_score_genes_Atlas_Scores_7', 'annotation_own_score_genes_start_iterative_Atlas_Scores_7', 'annotation_own_score_genes_Atlas_Scores_7', 'annotation_score_genes_original_BasicMartin_7', 'annotation_own_score_genes_BasicMartin_7', 'annotation_own_score_genes_start_iterative_BasicMartin_7', 'annotation_score_genes_original_HLMartin_7', 'annotation_own_score_genes_HLMartin_7', 'annotation_own_score_genes_start_iterative_HLMartin_7', 'annotation_tangram_11', 'annotation_tangram_7', 'distance_to_edge', 'distance_to_vein', 'area', 'eccentricity', 'extent', 'solidity', 'intensity_mean', 'Unknown_annotation_own_score_genes_BasicMartin_12', 'Unknown cells'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'mean', 'std'
#     uns: 'annotation_colors', 'annotation_own_score_genes_Atlas_12_colors', 'annotation_own_score_genes_Atlas_7_colors', 'annotation_own_score_genes_Atlas_Scores_12_colors', 'annotation_own_score_genes_Atlas_Scores_7_colors', 'annotation_own_score_genes_BasicMartin_12_colors', 'annotation_own_score_genes_BasicMartin_7_colors', 'annotation_own_score_genes_HLMartin_12_colors', 'annotation_own_score_genes_HLMartin_7_colors', 'annotation_own_score_genes_start_iterative_Atlas_12_colors', 'annotation_own_score_genes_start_iterative_Atlas_7_colors', 'annotation_own_score_genes_start_iterative_Atlas_Scores_12_colors', 'annotation_own_score_genes_start_iterative_Atlas_Scores_7_colors', 'annotation_own_score_genes_start_iterative_BasicMartin_12_colors', 'annotation_own_score_genes_start_iterative_BasicMartin_7_colors', 'annotation_own_score_genes_start_iterative_HLMartin_12_colors', 'annotation_own_score_genes_start_iterative_HLMartin_7_colors', 'annotation_score_genes_original_Atlas_12_colors', 'annotation_score_genes_original_Atlas_7_colors', 'annotation_score_genes_original_Atlas_Scores_12_colors', 'annotation_score_genes_original_Atlas_Scores_7_colors', 'annotation_score_genes_original_BasicMartin_12_colors', 'annotation_score_genes_original_BasicMartin_7_colors', 'annotation_score_genes_original_HLMartin_12_colors', 'annotation_score_genes_original_HLMartin_7_colors', 'annotation_tangram_11_colors', 'annotation_tangram_7_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'own_score_genes_Atlas_12', 'own_score_genes_Atlas_7', 'own_score_genes_Atlas_Scores_12', 'own_score_genes_Atlas_Scores_7', 'own_score_genes_BasicMartin_12', 'own_score_genes_HLMartin_12', 'own_score_genes_start_iterative_Atlas_12', 'own_score_genes_start_iterative_Atlas_7', 'own_score_genes_start_iterative_Atlas_Scores_12', 'own_score_genes_start_iterative_Atlas_Scores_7', 'own_score_genes_start_iterative_BasicMartin_12', 'own_score_genes_start_iterative_HLMartin_12', 'pca', 'rank_genes_groups', 'score_genes_original_Atlas_12', 'score_genes_original_Atlas_7', 'score_genes_original_Atlas_Scores_12', 'score_genes_original_Atlas_Scores_7', 'score_genes_original_BasicMartin_12', 'score_genes_original_HLMartin_12', 'spatialdata_attrs', 'tangram', 'umap', 'umap_15'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'raw_counts'
#     obsp: 'connectivities', 'distances': AnnData (11283, 99)
# with coordinate systems:
# ▸ 'global', with elements:
#         clahe (Images), min_max_filtered (Images), raw_image (Images), tiling_correction (Images), transcript_density (Images), segmentation_mask (Labels), transcripts (Points), expanded_cells20 (Shapes), filtered_segmentation_mask_boundaries_low_counts (Shapes), filtered_segmentation_mask_boundaries_segmentation (Shapes), filtered_segmentation_mask_boundaries_size (Shapes), segmentation_mask_boundaries (Shapes), to_plot_napari (Shapes)

# %%
del sdata.table
sdata.table = anndata
sdata.table
# Out:
# AnnData object with n_obs × n_vars = 11283 × 99
#     obs: 'region', 'instance', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_2_genes', 'pct_counts_in_top_5_genes', 'n_counts', 'shapeSize', 'leiden', 'portal_vein_EC45', 'LSEC45', 'LSEC Portal', 'LSEC Central', 'central_vein_EC45', 'stellateAll', 'stellate PeriPortal', 'stellate PeriCentral', 'FibroblastAll', 'fibroblastPortal', 'FibroblastsCentral', 'VSMC', 'capsular_fibroblasts45', 'Mesothelial cells', 'Hepatocytes', 'HepatocytesPortal', 'HepatocytesCentral', 'Cholangiocytes', 'cDC2s', 'Mig. cDCs', 'Neutrophils', 'Basophils', 'NK cells', 'ILC1s', 'T cells', 'pDCs', 'B cells', 'cDC1s', 'Kupffer cells', 'Capsule and Central Vein Mac', 'Portal LAM macrophages', 'Monocytes', 'LECs', 'cleanliness_score_genes_original_BasicMartin_12', 'annotation_score_genes_original_BasicMartin_12', 'annotationSave', 'Hep', 'score_celltype_own_score_genes_BasicMartin_12', 'second_score_celltype_own_score_genes_BasicMartin_12', 'cleanliness_own_score_genes_BasicMartin_12', 'annotation_own_score_genes_start_iterative_BasicMartin_12', 'annotation_own_score_genes_BasicMartin_12', 'annotation_score_genes_original_HLMartin_12', 'cleanliness_score_genes_original_HLMartin_12', 'score_celltype_own_score_genes_HLMartin_12', 'second_score_celltype_own_score_genes_HLMartin_12', 'cleanliness_own_score_genes_HLMartin_12', 'annotation_own_score_genes_start_iterative_HLMartin_12', 'annotation_own_score_genes_HLMartin_12', 'annotation_score_genes_original_Atlas_12', 'cleanliness_score_genes_original_Atlas_12', 'score_celltype_own_score_genes_Atlas_12', 'second_score_celltype_own_score_genes_Atlas_12', 'cleanliness_own_score_genes_Atlas_12', 'annotation_own_score_genes_start_iterative_Atlas_12', 'annotation_own_score_genes_Atlas_12', 'annotation_score_genes_original_Atlas_Scores_12', 'cleanliness_score_genes_original_Atlas_Scores_12', 'score_celltype_own_score_genes_Atlas_Scores_12', 'second_score_celltype_own_score_genes_Atlas_Scores_12', 'cleanliness_own_score_genes_Atlas_Scores_12', 'annotation_own_score_genes_start_iterative_Atlas_Scores_12', 'annotation_own_score_genes_Atlas_Scores_12', 'annotation_score_genes_original_Atlas_7', 'cleanliness_score_genes_original_Atlas_7', 'score_celltype_own_score_genes_Atlas_7', 'second_score_celltype_own_score_genes_Atlas_7', 'cleanliness_own_score_genes_Atlas_7', 'annotation_own_score_genes_start_iterative_Atlas_7', 'annotation_own_score_genes_Atlas_7', 'annotation_score_genes_original_Atlas_Scores_7', 'cleanliness_score_genes_original_Atlas_Scores_7', 'score_celltype_own_score_genes_Atlas_Scores_7', 'second_score_celltype_own_score_genes_Atlas_Scores_7', 'cleanliness_own_score_genes_Atlas_Scores_7', 'annotation_own_score_genes_start_iterative_Atlas_Scores_7', 'annotation_own_score_genes_Atlas_Scores_7', 'annotation_score_genes_original_BasicMartin_7', 'annotation_own_score_genes_BasicMartin_7', 'annotation_own_score_genes_start_iterative_BasicMartin_7', 'annotation_score_genes_original_HLMartin_7', 'annotation_own_score_genes_HLMartin_7', 'annotation_own_score_genes_start_iterative_HLMartin_7', 'annotation_tangram_11', 'annotation_tangram_7'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'mean', 'std'
#     uns: 'annotation_colors', 'annotation_own_score_genes_Atlas_12_colors', 'annotation_own_score_genes_Atlas_7_colors', 'annotation_own_score_genes_Atlas_Scores_12_colors', 'annotation_own_score_genes_Atlas_Scores_7_colors', 'annotation_own_score_genes_BasicMartin_12_colors', 'annotation_own_score_genes_BasicMartin_7_colors', 'annotation_own_score_genes_HLMartin_12_colors', 'annotation_own_score_genes_HLMartin_7_colors', 'annotation_own_score_genes_start_iterative_Atlas_12_colors', 'annotation_own_score_genes_start_iterative_Atlas_7_colors', 'annotation_own_score_genes_start_iterative_Atlas_Scores_12_colors', 'annotation_own_score_genes_start_iterative_Atlas_Scores_7_colors', 'annotation_own_score_genes_start_iterative_BasicMartin_12_colors', 'annotation_own_score_genes_start_iterative_BasicMartin_7_colors', 'annotation_own_score_genes_start_iterative_HLMartin_12_colors', 'annotation_own_score_genes_start_iterative_HLMartin_7_colors', 'annotation_score_genes_original_Atlas_12_colors', 'annotation_score_genes_original_Atlas_7_colors', 'annotation_score_genes_original_Atlas_Scores_12_colors', 'annotation_score_genes_original_Atlas_Scores_7_colors', 'annotation_score_genes_original_BasicMartin_12_colors', 'annotation_score_genes_original_BasicMartin_7_colors', 'annotation_score_genes_original_HLMartin_12_colors', 'annotation_score_genes_original_HLMartin_7_colors', 'annotation_tangram_11_colors', 'annotation_tangram_7_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'own_score_genes_Atlas_12', 'own_score_genes_Atlas_7', 'own_score_genes_Atlas_Scores_12', 'own_score_genes_Atlas_Scores_7', 'own_score_genes_BasicMartin_12', 'own_score_genes_HLMartin_12', 'own_score_genes_start_iterative_Atlas_12', 'own_score_genes_start_iterative_Atlas_7', 'own_score_genes_start_iterative_Atlas_Scores_12', 'own_score_genes_start_iterative_Atlas_Scores_7', 'own_score_genes_start_iterative_BasicMartin_12', 'own_score_genes_start_iterative_HLMartin_12', 'pca', 'rank_genes_groups', 'score_genes_original_Atlas_12', 'score_genes_original_Atlas_7', 'score_genes_original_Atlas_Scores_12', 'score_genes_original_Atlas_Scores_7', 'score_genes_original_BasicMartin_12', 'score_genes_original_HLMartin_12', 'spatialdata_attrs', 'tangram', 'umap', 'umap_15'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ## Open Napari and plot the images

# %%
viewer = napari.Viewer() # open napari
viewer.add_image(sdata['raw_image'])  # load in image
# Out:
# WARNING: Could not find the Qt platform plugin "wayland" in ""
# <Image layer 'Image' at 0x7abdf739f970>

# %% [markdown]
# ## Add cells to the mix

# %%
def prepare_napari_plot(sdata,cutoff_shapes=0.5,shapes_layer='segmentation_mask_boundaries',output_layer='to_plot_napari'):
    '''create polygons instead of multipolygons and simplify the shapes so the plotting is faster.'''
    temp=sdata[shapes_layer].explode()
    temp['Area']=temp.area
    temp=temp.sort_values(by='Area',ascending=False)
    temp.index=temp.index.droplevel(1)
    temp = temp[~temp.index.duplicated(keep='first')]
    if shapes_layer=='segmentation_mask_boundaries':
        temp=temp.reindex(sdata.table.obs.index)
    #adata=adata[temp.percent_area>cutoff_shapes,:]
    
    
    sdata.add_shapes(
                name=output_layer,
                shapes=sd.models.ShapesModel.parse(temp
                ),
                overwrite=True,
            )
    #adata.obsm['napari_plot']=temp2[['geometry','percent_area']]
    return sdata

# %%
def add_napari_layer(sdata,column=None,name=None,celltype=None,colormap='magma'):
    """
    Function to plot the cells into napari, colored by the correct olumn
    If you want a subset, just take a subset of the anndata before adding this. Don't use the function to change color, only to add an extra layer."""
    if celltype: 
        adata=sdata.table[sdata.table.obs['annotation_own_score_genes']==celltype,:]
        if not name:
            name=celltype
    else:
        adata=sdata.table
    coords_to_plot=[]
    to_color=None
    #adata.obsm['napari_plot']=geopandas.GeoDataFrame(adata.obsm['napari_plot'],geometry=adata.obsm['napari_plot']['geometry'])
    if column:
        if column + "_colors" in adata.uns:
                color_dict=dict(zip(adata.obs[column].cat.categories.values,adata.uns[column + "_colors"]))
                to_color=adata.obs[column].map(color_dict)
                print('colors from adata used')
    for i in sdata['to_plot_napari'].loc[adata.obs.index.values].geometry.exterior.simplify(tolerance=2):
        coords_to_plot.append(np.array(i.coords)[:,[1,0]]) 
    Columns=dict(zip(adata.var.index.values,adata.X.T))
    Columns.update(adata.obs.to_dict('list'))
    if not name:
        name=column
    if name in viewer.layers:
        viewer.layers[name].features=Columns
        if to_color:
            print('layer reused')
            viewer.layers[name].face_color=to_color.values
        if column in viewer.layers[name].features:
            print('layer reused')
            viewer.layers[name].face_color=column
            viewer.layers[name].face_colormap =colormap
    elif to_color is not None:
        viewer.add_shapes(coords_to_plot,name=name,shape_type='polygon',face_color=to_color.values.astype(str),opacity=0.7,edge_width=3,edge_color='white',features=Columns)
    elif column in Columns.keys():
        viewer.add_shapes(coords_to_plot,name=name,shape_type='polygon',face_color=column,opacity=0.7,edge_width=3,edge_color='white',features=Columns,face_colormap=colormap)
    elif column==None:
        viewer.add_shapes(coords_to_plot,name=name,shape_type='polygon',face_color=colormap,opacity=0.7,edge_width=3,edge_color='white',features=Columns)

# %%
annotation = 'annotation_own_score_genes_BasicMartin_12'
add_napari_layer(sdata,annotation)
# Out:
# colors from adata used

# %% [markdown]
# ## Add points into the mix

# %%
df=sdata.points['transcripts'].compute()

# %%
Vwf=['Vwf']
viewer.add_points(df[df['gene'].isin(Vwf)][['y','x']].values,size=50,face_color='red',name='Vwf') # I have put the size on 15, if you want to zoom less to see the spots, you can
# Out:
# <Points layer 'Vwf' at 0x7ddbf44a1c00>

# %% [markdown]
# ## Load polygons back into python

# %%
import rasterio
def mask_to_polygons_layer(mask: np.ndarray) -> geopandas.GeoDataFrame:
    """Returns the polygons as GeoDataFrame

    This function converts the mask to polygons.
    https://rocreguant.com/convert-a-mask-into-a-polygon-for-images-using-shapely-and-rasterio/1786/
    """

    all_polygons = []
    all_values = []

    # Extract the polygons from the mask
    for shape, value in features.shapes(
        mask.astype(np.int32),
        mask=(mask > 0),
        transform=rasterio.Affine(1.0, 0, 0, 0, 1.0, 0),
    ):
        all_polygons.append(shapely.geometry.shape(shape))
        all_values.append(int(value))

    return geopandas.GeoDataFrame(dict(geometry=all_polygons), index=all_values)

# %%
shape=sdata['raw_image'].shape

# %%
Edges = viewer.layers['edges'].to_labels(labels_shape=shape)

# %%
Veins = viewer.layers['veins'].to_labels(labels_shape=shape)

# %%
edges_shapes=mask_to_polygons_layer(Edges)
edges_shapes= edges_shapes.reset_index()

# %%
veins_shapes=mask_to_polygons_layer(Veins)
veins_shapes= veins_shapes.reset_index()

# %%
df=pd.DataFrame(index=sdata.table.obs.index)
for i in edges_shapes.index.values:
    df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
sdata.table.obs['distance_to_edge_tissue']=df.min(axis=1)
# Out:
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# ...
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)
# /tmp/ipykernel_23370/225033699.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(edges_shapes.loc[i].geometry)

# %%
df=pd.DataFrame(index=sdata.table.obs.index)
for i in veins_shapes.index.values:
    df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
sdata.table.obs['distance_to_vein']=df.min(axis=1)
# Out:
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)
# /tmp/ipykernel_9421/2534239685.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i]=sdata['segmentation_mask_boundaries'].distance(veins_shapes.loc[i].geometry)

# %%
def calculate_intensity(sdata):
    props = ['label','area', 'intensity_mean','eccentricity','extent','solidity']
    # area = shapeSize
    table=pd.DataFrame.from_dict(regionprops_table(sdata['segmentation_mask'].to_numpy(),intensity_image=sdata['clahe'].sel(c=0).to_numpy(),properties=props))
    table=table.set_index('label')
    table['filtered']=~table.index.isin(sdata.table.obs.index.values.astype(int))
    table = table[table['filtered']==False]
    table = table.drop(columns=['filtered'])
    return table

# %%
table_props = calculate_intensity(sdata)
sdata.table.obs['area'] = table_props['area'].to_list()
sdata.table.obs['eccentricity'] = table_props['eccentricity'].to_list()
sdata.table.obs['extent'] = table_props['extent'].to_list()
sdata.table.obs['solidity'] = table_props['solidity'].to_list()
sdata.table.obs['intensity_mean'] = table_props['intensity_mean'].to_list()

# %%
sdata.table.obs
# Out:
#       region  instance  n_genes_by_counts  log1p_n_genes_by_counts  \
# cells
# 335        1         1                  7                 2.079442
# 359        1         1                  5                 1.791759
# 431        1         1                  8                 2.197225
# 439        1         1                 11                 2.484907
# 471        1         1                  5                 1.791759
# ...      ...       ...                ...                      ...
# 35146      1         1                 16                 2.833213
# 35210      1         1                  6                 1.945910
# 35274      1         1                  4                 1.609438
# 35338      1         1                 20                 3.044522
# 35402      1         1                  7                 2.079442
#
#        total_counts  log1p_total_counts  pct_counts_in_top_2_genes  \
# cells
# 335              25            3.258097                  60.000000
# 359             247            5.513429                  90.688259
# 431              56            4.043051                  71.428571
# 439             216            5.379897                  69.907407
# 471             124            4.828314                  91.935484
# ...             ...                 ...                        ...
# 35146            47            3.871201                  38.297872
# 35210            43            3.784190                  76.744186
# 35274            13            2.639057                  76.923077
# 35338            90            4.510860                  44.444444
# 35402           140            4.948760                  91.428571
#
#        pct_counts_in_top_5_genes  n_counts  shapeSize  ...  \
# cells                                                  ...
# 335                    92.000000        25     3368.0  ...
# 359                   100.000000       247     3596.0  ...
# 431                    92.857143        56     2868.0  ...
# 439                    93.055556       216     3595.0  ...
# 471                   100.000000       124     3080.0  ...
# ...                          ...       ...        ...  ...
# 35146                  68.085106        47     2793.0  ...
# 35210                  97.674419        43     1357.0  ...
# 35274                 100.000000        13     1348.0  ...
# 35338                  67.777778        90     2372.0  ...
# 35402                  98.571429       140     2261.0  ...
#
#       annotation_own_score_genes_start_iterative_HLMartin_7  \
# cells
# 335                                                Strom
# 359                                              Unknown
# 431                                                 Hepa
# 439                                                 Hepa
# 471                                              Unknown
# ...                                                  ...
# 35146                                               Endo
# 35210                                               Endo
# 35274                                              Strom
# 35338                                              Strom
# 35402                                               Kupf
#
#        annotation_tangram_11  annotation_tangram_7  distance_to_edge  \
# cells
# 335                     Meso                 Strom          5.000000
# 359                     Hepa                  Hepa        107.000000
# 431                     Hepa                  Hepa        370.000000
# 439                     Hepa                  Hepa         91.000000
# 471                     Hepa                  Hepa        161.607549
# ...                      ...                   ...               ...
# 35146                   Hepa                  Hepa       4016.119645
# 35210            Portal vein                  Endo       4019.000000
# 35274                   Hepa                  Hepa       4026.152133
# 35338                   Fibr                 Strom       4028.000000
# 35402                   Hepa                  Hepa       4032.417141
#
#        distance_to_vein    area  eccentricity    extent  solidity  \
# cells
# 335          349.400916  3368.0      0.814145  0.690872  0.922993
# 359         1254.971713  3596.0      0.450551  0.704269  0.948813
# 431          538.282454  2868.0      0.411929  0.735385  0.977172
# 439         2579.544533  3595.0      0.393648  0.639566  0.914526
# 471         1320.898179  3080.0      0.874463  0.720131  0.962801
# ...                 ...     ...           ...       ...       ...
# 35146         10.049876  2793.0      0.846799  0.654098  0.969792
# 35210          0.000000  1357.0      0.340042  0.807738  0.976259
# 35274         19.209373  1348.0      0.770103  0.655005  0.932872
# 35338         55.000000  2372.0      0.746494  0.760256  0.931292
# 35402         87.664132  2261.0      0.505603  0.764368  0.974569
#
#        intensity_mean
# cells
# 335       3321.482185
# 359       5141.758621
# 431       5656.474895
# 439       5085.805563
# 471       4359.947403
# ...               ...
# 35146     7264.488006
# 35210     8306.563007
# 35274     3836.213650
# 35338     7913.673272
# 35402     8348.904909
#
# [11794 rows x 104 columns]

# %%
sns.boxplot(y=annotation,x='area',data=sdata.table.obs,whis=(5,90),showfliers=False)
plt.show()
sns.boxplot(y=annotation,x='eccentricity',data=sdata.table.obs,whis=(5,90),showfliers=False)
plt.show()
sns.boxplot(y=annotation,x='extent',data=sdata.table.obs,whis=(5,90),showfliers=False)
plt.show()
sns.boxplot(y=annotation,x='solidity',data=sdata.table.obs,whis=(5,90),showfliers=False)
plt.show()
sns.boxplot(y=annotation,x='intensity_mean',data=sdata.table.obs,whis=(5,90),showfliers=False)
plt.show()

# %%
sns.boxplot(y=annotation,x='distance_to_edge',data=sdata.table.obs,whis=(5,90),showfliers=True)
plt.show()

# %%
sns.boxplot(y=annotation,x='distance_to_vein',data=sdata.table.obs,whis=(5,90),showfliers=True)
plt.show()

# %%
sq.pl.spatial_scatter(anndata,color='distance_to_vein',shape=None, figsize=(10, 10))
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
sq.pl.spatial_scatter(anndata,color='distance_to_edge_tissue',shape=None, figsize=(10, 10))
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
anndata.write(OUTPUT_DIR + '/' + name_anndata + '_all_0threshold_distance_edge_tissue.h5ad')

# %%
anndata.obs
# Out:
#       region  instance  n_genes_by_counts  log1p_n_genes_by_counts  \
# cells
# 65         1         1                 17                 2.890372
# 66         1         1                 14                 2.708050
# 67         1         1                 18                 2.944439
# 129        1         1                 13                 2.639057
# 130        1         1                 29                 3.401197
# ...      ...       ...                ...                      ...
# 32713      1         1                 26                 3.295837
# 32777      1         1                 11                 2.484907
# 32841      1         1                 25                 3.258097
# 32905      1         1                 18                 2.944439
# 32969      1         1                 11                 2.484907
#
#        total_counts  log1p_total_counts  pct_counts_in_top_2_genes  \
# cells
# 65              100            4.615121                  50.000000
# 66               34            3.555348                  41.176471
# 67               52            3.970292                  50.000000
# 129              34            3.555348                  41.176471
# 130             142            4.962845                  48.591549
# ...             ...                 ...                        ...
# 32713           148            5.003946                  39.864865
# 32777           148            5.003946                  68.918919
# 32841           115            4.753590                  47.826087
# 32905            58            4.077537                  34.482759
# 32969           110            4.709530                  77.272727
#
#        pct_counts_in_top_5_genes  n_counts  shapeSize  ...  \
# cells                                                  ...
# 65                     76.000000       100     3728.0  ...
# 66                     70.588235        34     1157.0  ...
# 67                     71.153846        52     3066.0  ...
# 129                    67.647059        34     1786.0  ...
# 130                    61.971831       142     4065.0  ...
# ...                          ...       ...        ...  ...
# 32713                  63.513514       148     3743.0  ...
# 32777                  90.540541       148     4052.0  ...
# 32841                  69.565217       115     3277.0  ...
# 32905                  62.068966        58     2420.0  ...
# 32969                  92.727273       110     2960.0  ...
#
#       annotation_own_score_genes_Atlas_Scores_7  \
# cells
# 65                                      Unknown
# 66                                         Kupf
# 67                                      Unknown
# 129                                       Strom
# 130                                       Strom
# ...                                         ...
# 32713                                      Kupf
# 32777                                      Hepa
# 32841                                      Kupf
# 32905                                      Endo
# 32969                                      Hepa
#
#        annotation_score_genes_original_BasicMartin_7  \
# cells
# 65                                             Strom
# 66                                             Strom
# 67                                              Hepa
# 129                                            Strom
# 130                                            Strom
# ...                                              ...
# 32713                                           Kupf
# 32777                                           Hepa
# 32841                                           Kupf
# 32905                                          Strom
# 32969                                           Hepa
#
#        annotation_own_score_genes_BasicMartin_7  \
# cells
# 65                                        Strom
# 66                                        Strom
# 67                                        Strom
# 129                                       Strom
# 130                                       Strom
# ...                                         ...
# 32713                                      Kupf
# 32777                                      Hepa
# 32841                                      Kupf
# 32905                                      Hepa
# 32969                                      Hepa
#
#        annotation_own_score_genes_start_iterative_BasicMartin_7  \
# cells
# 65                                                 Strom
# 66                                                 Strom
# 67                                                 Strom
# 129                                                Strom
# 130                                                Strom
# ...                                                  ...
# 32713                                               Kupf
# 32777                                               Hepa
# 32841                                               Kupf
# 32905                                               Endo
# 32969                                               Chol
#
#        annotation_score_genes_original_HLMartin_7  \
# cells
# 65                                          Strom
# 66                                           Hepa
# 67                                           Hepa
# 129                                         Strom
# 130                                         Strom
# ...                                           ...
# 32713                                        Kupf
# 32777                                        Hepa
# 32841                                        Kupf
# 32905                                        Hepa
# 32969                                        Hepa
#
#        annotation_own_score_genes_HLMartin_7  \
# cells
# 65                                     Strom
# 66                                     Strom
# 67                                     Strom
# 129                                    Strom
# 130                                    Strom
# ...                                      ...
# 32713                                   Kupf
# 32777                                   Hepa
# 32841                                   Kupf
# 32905                                   Endo
# 32969                                   Hepa
#
#        annotation_own_score_genes_start_iterative_HLMartin_7  \
# cells
# 65                                                 Strom
# 66                                                 Strom
# 67                                                 Strom
# 129                                                Strom
# 130                                                Strom
# ...                                                  ...
# 32713                                               Kupf
# 32777                                               Hepa
# 32841                                               Kupf
# 32905                                               Endo
# 32969                                               Chol
#
#        annotation_tangram_11  annotation_tangram_7  distance_to_edge_tissue
# cells
# 65                      Meso                 Strom                 0.000000
# 66                      Hepa                  Hepa                51.788030
# 67                      Meso                 Strom                 0.000000
# 129                     Meso                 Strom                 0.000000
# 130                     Fibr                 Strom                 0.000000
# ...                      ...                   ...                      ...
# 32713                   Hepa                  Hepa              3391.288841
# 32777                   Hepa                  Hepa              3267.820834
# 32841                   Kupf                  Kupf              3212.937130
# 32905                   Hepa                  Hepa              3270.052140
# 32969                   Hepa                  Hepa              3199.076898
#
# [11283 rows x 97 columns]
